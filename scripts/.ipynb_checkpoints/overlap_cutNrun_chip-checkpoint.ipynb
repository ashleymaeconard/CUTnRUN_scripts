# %%
# Clear all variables
import sys
sys.modules[__name__].__dict__.clear()
print(dir())
print(globals())
print(locals())
# Out:
# ['__builtins__']
# ...

# %%
# overlap_cutNrun_chip
# Ashley Conard
# Last Mod: June 27, 2019
# Resources: https://github.com/tctianchi/pyvenn
#            intervene
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.lines import Line2D
import random
import contrasting_colors
import seaborn as sns
import glob, sys
import re
import os
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
from matplotlib import pyplot
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt 
import importlib.util

def module_from_file(module_name, file_path):
    spec = importlib.util.spec_from_file_location(module_name, file_path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return module

# Imported from github file (empty )
venn = module_from_file("foo", "/data/compbio/aconard/tools/pyvenn/venn.py")

# %%
# Change these boxes only
INPUT_DIR_CUTNRUN ="/data/compbio/aconard/chip_soruco_2013/results/macs2/"
INPUT_DIR_CHIP ="/data/compbio/aconard/cut-n-run/results/macs2/"
PAIRED = 0 # change to 1 if paired-end sequencing

# Do not change #########
if not os.path.exists(INPUT_DIR_CUTNRUN+"/overlap_cut_chip/"):
    os.makedirs(INPUT_DIR_CUTNRUN+"/overlap_cut_chip/")
if not os.path.exists(INPUT_DIR_CHIP+"/overlap_cut_chip/"):
    os.makedirs(INPUT_DIR_CHIP+"/overlap_cut_chip/")

# %%
for file in glob.glob(INPUT_DIR_CUTNRUN+"/*/*/*narrowPeak*"):
    print(file)
# Out:
# /data/compbio/aconard/chip_soruco_2013/results/macs2/clampChip_f/SRR520445/out.sorted.bam_peaks.narrowPeak
# /data/compbio/aconard/chip_soruco_2013/results/macs2/clampChip_f/SRR520447/out.sorted.bam_peaks.narrowPeak
# /data/compbio/aconard/chip_soruco_2013/results/macs2/clampChip_m/SRR520453/out.sorted.bam_peaks.narrowPeak
# /data/compbio/aconard/chip_soruco_2013/results/macs2/clampChip_m/SRR520455/out.sorted.bam_peaks.narrowPeak

# %%
labels = venn.get_labels([
            range(10),
            range(5, 15)
        ], fill=['number', 'logic'])

# %%
print(labels)
# Out:
# {'01': '01: 5', '10': '10: 5', '11': '11: 5'}

# %%
labels = venn.get_labels([range(10), range(5, 15), range(3, 8), range(8, 17), range(10, 20), range(13, 25)], fill=['number', 'logic'])
fig, ax = venn.venn6(labels, names=['list 1', 'list 2', 'list 3', 'list 4', 'list 5', 'list 6'])
fig.show()
